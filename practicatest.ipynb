# %% [markdown]
# <a href="https://colab.research.google.com/github/ari123beathea-rgb/cs1-python-emerald-masecampo/blob/main/practicatest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
result = (input ( "are you scared for the practical test? " ))

if result == 'yes':
  print ("its okay boy kaya mo yan.!")

else:
  print ("oh you fat chud stop lying")
# Out:
# are you scared for the practical test? yes
# its okay boy kaya mo yan.!

# %%
A = int(input ("How many numbers do you wish to enter?"))

number = A
def whatsthenumber (promptnumber):
  actual_user_input = int(input (f"What is number {promptnumber}? "))
  return actual_user_input


def evenodd (inputnumber):
  if (inputnumber) % 2 == 0:
    print ("The number is even")
  else:
    print ("The number is odd")

user_input_number = whatsthenumber (number)
evenodd (user_input_number)

number2 = A - 1

user_input_number2 = whatsthenumber (number2)
evenodd (user_input_number2)

number3 = A - 2

user_input_number3 = whatsthenumber (number3)
evenodd (user_input_number3)

def average (inputnumber, inputnumber2, inputnumber3):
  average = (inputnumber + inputnumber2 + inputnumber3)
  overallaverage = average / 3
  return overallaverage

  print ("The overall average is {overallaverage}.")
# Out:
# How many numbers do you wish to enter?4
# What is number 4? 3
# The number is odd
# What is number 3? 5
# The number is odd
# What is number 2? 2
# The number is even
