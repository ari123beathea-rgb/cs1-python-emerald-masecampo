# %% [markdown]
# <a href="https://colab.research.google.com/github/ari123beathea-rgb/cs1-python-emerald-masecampo/blob/main/MASECAMPO_FA2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = int(input ("enter first number:"))
num2 = int(input ("enter second number:"))
num3 = int(input ("enter third number:"))

if num1 > num2 and num1 > num3:
 print (num1, "is the greatest number")

elif num2 > num1 and num2 > num3:
    print (num2, "is the greatest number")

else:
    print (num3, "is the greatest number")
# Out:
# enter first number:12
# enter second number:11
# enter third number:10
# 12 is the greatest number
